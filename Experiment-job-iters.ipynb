# %% [markdown]
# ### Iteration Group

# %%
import copy
import os
import re
from pathlib import Path

import numpy as np
import pandas as pd
from HybridCloud import *
import matplotlib.pyplot as plt

# -----------------------------
# Helpers: per-job DF + summary
# -----------------------------

def build_job_energy_df(job_records: dict) -> pd.DataFrame:
    rows = []
    for job_id, rec in job_records.items():
        e_qpu = float(rec.get("energy_qpu_kwh", 0.0) or 0.0)
        e_cpu = float(rec.get("energy_cpu_kwh", 0.0) or 0.0)
        e_tot = float(rec.get("energy_total_kwh", e_qpu + e_cpu) or (e_qpu + e_cpu))
        c_tot = float(rec.get("cost_energy_total", 0.0) or 0.0)

        # Avoid divide-by-zero
        if e_tot > 0:
            phi_qpu = e_qpu / e_tot
            phi_cpu = e_cpu / e_tot
        else:
            phi_qpu = 0.0
            phi_cpu = 0.0

        # ---- NEW: wait/turn/makespan from your record structure ----
        qpu_wait_list = rec.get("qpu_wait", []) or []
        cpu_wait_list = rec.get("cpu_wait", []) or []
        qpu_turn_list = rec.get("qpu_turn", []) or []
        cpu_turn_list = rec.get("cpu_turn", []) or []
        makespan_list = rec.get("makespan", []) or []

        qpu_wait_s = float(np.sum(qpu_wait_list)) if isinstance(qpu_wait_list, list) else float(qpu_wait_list or 0.0)
        cpu_wait_s = float(np.sum(cpu_wait_list)) if isinstance(cpu_wait_list, list) else float(cpu_wait_list or 0.0)

        # "turn" here is per-segment turnaround; sum gives total turnaround across all segments
        qpu_turn_s = float(np.sum(qpu_turn_list)) if isinstance(qpu_turn_list, list) else float(qpu_turn_list or 0.0)
        cpu_turn_s = float(np.sum(cpu_turn_list)) if isinstance(cpu_turn_list, list) else float(cpu_turn_list or 0.0)

        # Job-level end-to-end turnaround time (your record calls it makespan)
        job_turnaround_s = float(makespan_list[0]) if isinstance(makespan_list, list) and len(makespan_list) > 0 else float(rec.get("makespan", 0.0) or 0.0)

        rows.append({
            "job_id": job_id,
            "energy_qpu_kwh": e_qpu,
            "energy_cpu_kwh": e_cpu,
            "energy_total_kwh": e_tot,
            "cost_energy_total": c_tot,
            "phi_qpu": phi_qpu,
            "phi_cpu": phi_cpu,
            "qpu_time_s": float(rec.get("qpu_time_s", 0.0) or 0.0),
            "cpu_time_s": float(rec.get("cpu_time_s", 0.0) or 0.0),

            # ---- NEW columns ----
            "qpu_wait_s": qpu_wait_s,
            "cpu_wait_s": cpu_wait_s,
            "wait_total_s": qpu_wait_s + cpu_wait_s,
            "qpu_turn_s": qpu_turn_s,
            "cpu_turn_s": cpu_turn_s,
            "turn_total_s": qpu_turn_s + cpu_turn_s,
            "job_turnaround_s": job_turnaround_s,   # end-to-end
        })

    df = pd.DataFrame(rows).sort_values("job_id").reset_index(drop=True)
    return df

def get_summary(df: pd.DataFrame) -> dict:
    def p95(x):
        return float(np.percentile(x, 95))

    summary = {
        "number_of_jobs": int(len(df)),

        # ---- Mean energy ----
        "mean_energy_qpu_kwh": float(df["energy_qpu_kwh"].mean()),
        "mean_energy_cpu_kwh": float(df["energy_cpu_kwh"].mean()),
        "mean_energy_total_kwh": float(df["energy_total_kwh"].mean()),

        # ---- Std deviation (energy variability) ----
        "std_energy_qpu_kwh": float(df["energy_qpu_kwh"].std()),
        "std_energy_cpu_kwh": float(df["energy_cpu_kwh"].std()),
        "std_energy_total_kwh": float(df["energy_total_kwh"].std()),

        # ---- Cost statistics ----
        "mean_cost_per_job": float(df["cost_energy_total"].mean()),
        "std_cost_per_job": float(df["cost_energy_total"].std()),        
        "median_cost_per_job": float(df["cost_energy_total"].median()),
        "p95_cost_per_job": p95(df["cost_energy_total"]),

        # ---- Energy fractions ----
        "mean_phi_qpu": float(df["phi_qpu"].mean()),
        "mean_phi_cpu": float(df["phi_cpu"].mean()),
        "std_phi_qpu": float(df["phi_qpu"].std()),
        "std_phi_cpu": float(df["phi_cpu"].std()),        

        # ---- Time statistics ----
        "mean_qpu_time_s": float(df["qpu_time_s"].mean()),
        "mean_cpu_time_s": float(df["cpu_time_s"].mean()),
        "std_qpu_time_s": float(df["qpu_time_s"].std()),
        "std_cpu_time_s": float(df["cpu_time_s"].std()),        
        "p95_qpu_time_s": p95(df["qpu_time_s"]),
        "p95_cpu_time_s": p95(df["cpu_time_s"]),
    }

    # ---- NEW: wait + turnaround summaries (only if columns exist) ----
    if "qpu_wait_s" in df.columns:
        summary.update({
            "mean_qpu_wait_s": float(df["qpu_wait_s"].mean()),
            "mean_cpu_wait_s": float(df["cpu_wait_s"].mean()),
            "mean_wait_total_s": float(df["wait_total_s"].mean()),
            "std_qpu_wait_s": float(df["qpu_wait_s"].std()),
            "std_cpu_wait_s": float(df["cpu_wait_s"].std()),
            "std_wait_total_s": float(df["wait_total_s"].std()),
            "p95_wait_total_s": p95(df["wait_total_s"]),
        })

    # Job-level end-to-end turnaround (your record's 'makespan')
    if "job_turnaround_s" in df.columns:
        summary.update({
            "mean_job_turnaround_s": float(df["job_turnaround_s"].mean()),
            "std_job_turnaround_s": float(df["job_turnaround_s"].std()),
            "median_job_turnaround_s": float(df["job_turnaround_s"].median()),
            "p95_job_turnaround_s": p95(df["job_turnaround_s"]),
        })

    # Segment-level turnaround sums (optional but nice for diagnosing pipeline overhead)
    if "turn_total_s" in df.columns:
        summary.update({
            "mean_turn_total_s": float(df["turn_total_s"].mean()),
            "std_turn_total_s": float(df["turn_total_s"].std()),
            "p95_turn_total_s": p95(df["turn_total_s"]),
        })

    # Optional: fraction of end-to-end time spent waiting (queueing)
    if "wait_total_s" in df.columns and "job_turnaround_s" in df.columns:
        denom = df["job_turnaround_s"].replace(0, np.nan)
        wait_frac = (df["wait_total_s"] / denom).fillna(0.0)
        summary.update({
            "mean_wait_fraction": float(wait_frac.mean()),
            "std_wait_fraction": float(wait_frac.std()),
            "p95_wait_fraction": p95(wait_frac),
        })

    print("\n=== Energy/Cost Summary ===")
    for k, v in summary.items():
        if isinstance(v, float):
            print(f"{k:>22}: {v:.6f}")
        else:
            print(f"{k:>22}: {v}")
    return summary

def extract_iterations_from_filename(path: str) -> int:
    """
    Extracts k from filenames like:
      5000-job_iter_3.csv
      synth_job_batches/5000-job_iter_12.csv
    """
    m = re.search(r"iter_(\d+)", str(path))
    if not m:
        raise ValueError(f"Could not extract iterations from filename: {path}")
    return int(m.group(1))


PRINTLOG = False

# -----------------------------
# 0) Devices (create fresh per run recommended)
# -----------------------------
def make_devices(printlog=PRINTLOG):
    # QPUs
    ibm_strasbourg = IBM_Strasbourg(env=None, name="QPU-1", printlog=printlog)
    ibm_brussels   = IBM_Brussels(env=None, name="QPU-2", printlog=printlog)
    # CPUs
    ryzen1 = AMDRyzen("CPU-1", env=None)
    ryzen2 = AMDRyzen("CPU-2", env=None)
    return [ibm_strasbourg, ibm_brussels], [ryzen1, ryzen2]


# -----------------------------
# 1) Base cost_config (fixed for this experiment)
# -----------------------------
base_cost_config = {
  "energy": {
    "electricity_price_per_kwh": 0.18,
    "default_qpu_power_kw": 50.0,
    "qpu_power_kw": {"QPU-1": 70.0, "QPU-2": 60.0},
    "cpu_power_kw": {"CPU-1": 5.0, "CPU-2": 6.5},
    "cpu_power_model": "affine",
    "default_cpu_idle_kw": 0.22,
    "default_cpu_peak_kw": 0.75,
    "default_cpu_capacity_units": 16,
    "debug_energy": False
  }
}


# -----------------------------
# 2) Create env for a run
# -----------------------------
def make_env(file_path: str, cost_config: dict, printlog=PRINTLOG):
    qpus, cpus = make_devices(printlog=printlog)
    sim_env = HybridCloudSimEnv(
        qpu_devices=qpus,
        cpu_devices=cpus,
        broker_class=HybridBroker,
        job_feed_method='dispatcher',
        file_path=file_path,
        job_generation_model=None,
        printlog=printlog,
        cost_config=cost_config
    )
    return sim_env


# -----------------------------
# 3) Iteration-group runner
# -----------------------------
def run_iteration_groups(job_csv_list, *, save_per_job_csv=True, out_dir="runs") -> pd.DataFrame:
    """
    Runs one simulation per CSV (each CSV corresponds to a fixed req_iterations group).
    Returns a summary DataFrame with one row per iteration group.
    """
    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)

    rows = []

    for csv_path in job_csv_list:
        k = extract_iterations_from_filename(csv_path)

        cost_config = copy.deepcopy(base_cost_config)  # keep identical across groups

        print(f"\n=== Running iteration group: k={k} | file={csv_path} ===")
        sim_env = make_env(file_path=csv_path, cost_config=cost_config, printlog=PRINTLOG)

        # Optional sanity prints
        energy_cfg = sim_env.cost_config.get("energy", {})
        print(f"electricity_price_per_kwh: {energy_cfg.get('electricity_price_per_kwh')}")
        print(f"cpu_power_model: {energy_cfg.get('cpu_power_model')}")
        print(f"default_cpu_idle_kw: {energy_cfg.get('default_cpu_idle_kw')}")

        sim_env.run()

        job_records = sim_env.job_records_manager.job_records
        df_jobs = build_job_energy_df(job_records)

        # Save per-job records for plotting p50/p95 curves later
        if save_per_job_csv:
            per_job_path = out_dir / f"results_iter_{k}_jobs.csv"
            df_jobs.to_csv(per_job_path, index=False)
            print(f"Saved per-job records: {per_job_path} ({len(df_jobs)} jobs)")

        summary = get_summary(df_jobs)
        summary["iterations"] = k
        summary["workload_csv"] = str(csv_path)
        rows.append(summary)

    df_summary = pd.DataFrame(rows).sort_values("iterations").reset_index(drop=True)
    return df_summary


# -----------------------------
# 4) Execute iteration sweep
# -----------------------------
JOB_CSV = [
    "synth_job_batches/iter-job-batches/3000-job_iter_3.csv",
    "synth_job_batches/iter-job-batches/3000-job_iter_6.csv",
    "synth_job_batches/iter-job-batches/3000-job_iter_9.csv",
    "synth_job_batches/iter-job-batches/3000-job_iter_12.csv",
    "synth_job_batches/iter-job-batches/3000-job_iter_15.csv",
    "synth_job_batches/iter-job-batches/3000-job_iter_18.csv", 
    "synth_job_batches/iter-job-batches/3000-job_iter_21.csv"
]

df_sweep = run_iteration_groups(JOB_CSV, save_per_job_csv=True, out_dir="runs")
# Out:
# === Running iteration group: k=3 | file=synth_job_batches/iter-job-batches/3000-job_iter_3.csv ===
# electricity_price_per_kwh: 0.18
# cpu_power_model: affine
# default_cpu_idle_kw: 0.22
# 2 QPU(s), 2 CPU(s)
# 0.00: SIMULATION STARTED
# 0 has been processed.
# 500 has been processed.
# 1000 has been processed.
# 1500 has been processed.
# 2000 has been processed.
# 2500 has been processed.
# 2887.59: SIMULATION ENDED
# Number of jobs processed: 3000
#
# ============================================================
#                  FINAL QUANTUM CLOUD SUMMARY
# ============================================================
# Total Operational Lifetime : 2887.59 seconds
# Global Cumulative QPU Util : 15.8%
# Global Cumulative CPU Util : 1.8%
# Global Cumulative Mem Util : 2.52%
# ------------------------------------------------------------
# Individual Device Endstates:
# ============================================================
#
# Saved per-job records: runs/results_iter_3_jobs.csv (3000 jobs)
#
# === Energy/Cost Summary ===
#         number_of_jobs: 3000
#    mean_energy_qpu_kwh: 0.052683
#    mean_energy_cpu_kwh: 0.000701
#  mean_energy_total_kwh: 0.053388
#     std_energy_qpu_kwh: 0.022380
#     std_energy_cpu_kwh: 0.001199
#   std_energy_total_kwh: 0.022400
#      mean_cost_per_job: 0.009610
#       std_cost_per_job: 0.004033
#    median_cost_per_job: 0.009600
#       p95_cost_per_job: 0.016200
#           mean_phi_qpu: 0.984286
#           mean_phi_cpu: 0.015612
#            std_phi_qpu: 0.029479
#            std_phi_cpu: 0.029556
#        mean_qpu_time_s: 2.911658
#        mean_cpu_time_s: 0.466760
#         std_qpu_time_s: 1.221650
#         std_cpu_time_s: 0.789052
#         p95_qpu_time_s: 4.909100
#         p95_cpu_time_s: 2.337765
#        mean_qpu_wait_s: 0.000000
#        mean_cpu_wait_s: 0.000000
#      mean_wait_total_s: 0.000000
#         std_qpu_wait_s: 0.000000
#         std_cpu_wait_s: 0.000000
#       std_wait_total_s: 0.000000
#       p95_wait_total_s: 0.000000
#  mean_job_turnaround_s: 3.378382
#   std_job_turnaround_s: 1.450194
# median_job_turnaround_s: 3.338100
#   p95_job_turnaround_s: 5.768800
#      mean_turn_total_s: 3.378418
#       std_turn_total_s: 1.450038
#       p95_turn_total_s: 5.764845
#     mean_wait_fraction: 0.000000
#      std_wait_fraction: 0.000000
#      p95_wait_fraction: 0.000000
#
# === Running iteration group: k=6 | file=synth_job_batches/iter-job-batches/3000-job_iter_6.csv ===
# electricity_price_per_kwh: 0.18
# cpu_power_model: affine
# default_cpu_idle_kw: 0.22
# 2 QPU(s), 2 CPU(s)
# 0.00: SIMULATION STARTED
# 0 has been processed.
# 500 has been processed.
# 1000 has been processed.
# 1500 has been processed.
# 2000 has been processed.
# 2500 has been processed.
# 2891.10: SIMULATION ENDED
# Number of jobs processed: 3000
#
# ============================================================
#                  FINAL QUANTUM CLOUD SUMMARY
# ============================================================
# Total Operational Lifetime : 2891.10 seconds
# Global Cumulative QPU Util : 33.94%
# Global Cumulative CPU Util : 2.76%
# Global Cumulative Mem Util : 4.08%
# ------------------------------------------------------------
# Individual Device Endstates:
# ============================================================
#
# Saved per-job records: runs/results_iter_6_jobs.csv (3000 jobs)
#
# === Energy/Cost Summary ===
#         number_of_jobs: 3000
#    mean_energy_qpu_kwh: 0.105558
#    mean_energy_cpu_kwh: 0.001463
#  mean_energy_total_kwh: 0.107026
#     std_energy_qpu_kwh: 0.044376
#     std_energy_cpu_kwh: 0.002446
#   std_energy_total_kwh: 0.044470
#      mean_cost_per_job: 0.019265
#       std_cost_per_job: 0.008005
#    median_cost_per_job: 0.019050
#       p95_cost_per_job: 0.032205
#           mean_phi_qpu: 0.983972
#           mean_phi_cpu: 0.015968
#            std_phi_qpu: 0.029223
#            std_phi_cpu: 0.029275
#        mean_qpu_time_s: 5.845311
#        mean_cpu_time_s: 0.943737
#         std_qpu_time_s: 2.450129
#         std_cpu_time_s: 1.569367
#         p95_qpu_time_s: 9.818205
#         p95_cpu_time_s: 4.731710
#        mean_qpu_wait_s: 0.000000
#        mean_cpu_wait_s: 0.000000
#      mean_wait_total_s: 0.000000
#         std_qpu_wait_s: 0.000000
#         std_cpu_wait_s: 0.000000
#       std_wait_total_s: 0.000000
#       p95_wait_total_s: 0.000000
#  mean_job_turnaround_s: 6.789345
#   std_job_turnaround_s: 2.922198
# median_job_turnaround_s: 6.712150
#   p95_job_turnaround_s: 11.573460
#      mean_turn_total_s: 6.789048
#       std_turn_total_s: 2.921384
#       p95_turn_total_s: 11.569535
#     mean_wait_fraction: 0.000000
#      std_wait_fraction: 0.000000
#      p95_wait_fraction: 0.000000
#
# === Running iteration group: k=9 | file=synth_job_batches/iter-job-batches/3000-job_iter_9.csv ===
# electricity_price_per_kwh: 0.18
# cpu_power_model: affine
# default_cpu_idle_kw: 0.22
# 2 QPU(s), 2 CPU(s)
# 0.00: SIMULATION STARTED
# 0 has been processed.
# 500 has been processed.
# 1000 has been processed.
# 1500 has been processed.
# 2000 has been processed.
# 2500 has been processed.
# 2896.63: SIMULATION ENDED
# Number of jobs processed: 3000
#
# ============================================================
#                  FINAL QUANTUM CLOUD SUMMARY
# ============================================================
# Total Operational Lifetime : 2896.63 seconds
# Global Cumulative QPU Util : 52.09%
# Global Cumulative CPU Util : 4.12%
# Global Cumulative Mem Util : 6.05%
# ------------------------------------------------------------
# Individual Device Endstates:
# ============================================================
#
# Saved per-job records: runs/results_iter_9_jobs.csv (3000 jobs)
#
# === Energy/Cost Summary ===
#         number_of_jobs: 3000
#    mean_energy_qpu_kwh: 0.164327
#    mean_energy_cpu_kwh: 0.002207
#  mean_energy_total_kwh: 0.166538
#     std_energy_qpu_kwh: 0.071094
#     std_energy_cpu_kwh: 0.003657
#   std_energy_total_kwh: 0.071509
#      mean_cost_per_job: 0.029977
#       std_cost_per_job: 0.012872
#    median_cost_per_job: 0.029750
#       p95_cost_per_job: 0.050300
#           mean_phi_qpu: 0.985091
#           mean_phi_cpu: 0.014885
#            std_phi_qpu: 0.026966
#            std_phi_cpu: 0.026981
#        mean_qpu_time_s: 9.099635
#        mean_cpu_time_s: 1.402048
#         std_qpu_time_s: 3.922020
#         std_cpu_time_s: 2.312906
#         p95_qpu_time_s: 15.352900
#         p95_cpu_time_s: 7.122260
#        mean_qpu_wait_s: 0.000000
#        mean_cpu_wait_s: 0.000000
#      mean_wait_total_s: 0.000000
#         std_qpu_wait_s: 0.000000
#         std_cpu_wait_s: 0.000000
#       std_wait_total_s: 0.000000
#       p95_wait_total_s: 0.000000
#  mean_job_turnaround_s: 10.515147
#   std_job_turnaround_s: 4.752702
# median_job_turnaround_s: 10.284350
#   p95_job_turnaround_s: 18.645825
#      mean_turn_total_s: 10.501683
#       std_turn_total_s: 4.728166
#       p95_turn_total_s: 18.533880
#     mean_wait_fraction: 0.000000
#      std_wait_fraction: 0.000000
#      p95_wait_fraction: 0.000000
#
# === Running iteration group: k=12 | file=synth_job_batches/iter-job-batches/3000-job_iter_12.csv ===
# electricity_price_per_kwh: 0.18
# cpu_power_model: affine
# default_cpu_idle_kw: 0.22
# 2 QPU(s), 2 CPU(s)
# 0.00: SIMULATION STARTED
# 0 has been processed.
# 500 has been processed.
# 1000 has been processed.
# 1500 has been processed.
# 2000 has been processed.
# 2500 has been processed.
# 2900.73: SIMULATION ENDED
# Number of jobs processed: 3000
#
# ============================================================
#                  FINAL QUANTUM CLOUD SUMMARY
# ============================================================
# Total Operational Lifetime : 2900.73 seconds
# Global Cumulative QPU Util : 70.25%
# Global Cumulative CPU Util : 5.63%
# Global Cumulative Mem Util : 8.19%
# ------------------------------------------------------------
# Individual Device Endstates:
# ============================================================
#
# Saved per-job records: runs/results_iter_12_jobs.csv (3000 jobs)
#
# === Energy/Cost Summary ===
#         number_of_jobs: 3000
#    mean_energy_qpu_kwh: 0.306550
#    mean_energy_cpu_kwh: 0.002944
#  mean_energy_total_kwh: 0.309496
#     std_energy_qpu_kwh: 0.213567
#     std_energy_cpu_kwh: 0.004820
#   std_energy_total_kwh: 0.215641
#      mean_cost_per_job: 0.055710
#       std_cost_per_job: 0.038815
#    median_cost_per_job: 0.047900
#       p95_cost_per_job: 0.130965
#           mean_phi_qpu: 0.990819
#           mean_phi_cpu: 0.009166
#            std_phi_qpu: 0.016497
#            std_phi_cpu: 0.016498
#        mean_qpu_time_s: 16.953622
#        mean_cpu_time_s: 1.860131
#         std_qpu_time_s: 11.766810
#         std_cpu_time_s: 3.042664
#         p95_qpu_time_s: 40.066830
#         p95_cpu_time_s: 9.607115
#        mean_qpu_wait_s: 0.000000
#        mean_cpu_wait_s: 0.000000
#      mean_wait_total_s: 0.000000
#         std_qpu_wait_s: 0.000000
#         std_cpu_wait_s: 0.000000
#       std_wait_total_s: 0.000000
#       p95_wait_total_s: 0.000000
#  mean_job_turnaround_s: 18.981884
#   std_job_turnaround_s: 13.629798
# median_job_turnaround_s: 15.941600
#   p95_job_turnaround_s: 45.716705
#      mean_turn_total_s: 18.813753
#       std_turn_total_s: 13.336367
#       p95_turn_total_s: 45.181250
#     mean_wait_fraction: 0.000000
#      std_wait_fraction: 0.000000
#      p95_wait_fraction: 0.000000
#
# === Running iteration group: k=15 | file=synth_job_batches/iter-job-batches/3000-job_iter_15.csv ===
# electricity_price_per_kwh: 0.18
# cpu_power_model: affine
# default_cpu_idle_kw: 0.22
# 2 QPU(s), 2 CPU(s)
# 0.00: SIMULATION STARTED
# 0 has been processed.
# 500 has been processed.
# 1000 has been processed.
# 1500 has been processed.
# 2000 has been processed.
# 2500 has been processed.
# 3012.47: SIMULATION ENDED
# Number of jobs processed: 3000
#
# ============================================================
#                  FINAL QUANTUM CLOUD SUMMARY
# ============================================================
# Total Operational Lifetime : 3012.47 seconds
# Global Cumulative QPU Util : 85.18%
# Global Cumulative CPU Util : 7.39%
# Global Cumulative Mem Util : 10.75%
# ------------------------------------------------------------
# Individual Device Endstates:
# ============================================================
#
# Saved per-job records: runs/results_iter_15_jobs.csv (3000 jobs)
#
# === Energy/Cost Summary ===
#         number_of_jobs: 3000
#    mean_energy_qpu_kwh: 2.053575
#    mean_energy_cpu_kwh: 0.003719
#  mean_energy_total_kwh: 2.057297
#     std_energy_qpu_kwh: 2.175013
#     std_energy_cpu_kwh: 0.006081
#   std_energy_total_kwh: 2.179072
#      mean_cost_per_job: 0.370314
#       std_cost_per_job: 0.392232
#    median_cost_per_job: 0.192950
#       p95_cost_per_job: 1.175045
#           mean_phi_qpu: 0.998690
#           mean_phi_cpu: 0.001300
#            std_phi_qpu: 0.002524
#            std_phi_cpu: 0.002532
#        mean_qpu_time_s: 113.700267
#        mean_cpu_time_s: 2.342834
#         std_qpu_time_s: 120.569780
#         std_cpu_time_s: 3.825180
#         p95_qpu_time_s: 361.122620
#         p95_cpu_time_s: 12.046415
#        mean_qpu_wait_s: 0.000000
#        mean_cpu_wait_s: 0.000000
#      mean_wait_total_s: 0.000000
#         std_qpu_wait_s: 0.000000
#         std_cpu_wait_s: 0.000000
#       std_wait_total_s: 0.000000
#       p95_wait_total_s: 0.000000
#  mean_job_turnaround_s: 119.596898
#   std_job_turnaround_s: 126.561170
# median_job_turnaround_s: 61.887700
#   p95_job_turnaround_s: 375.860725
#      mean_turn_total_s: 116.043101
#       std_turn_total_s: 123.160684
#       p95_turn_total_s: 367.540435
#     mean_wait_fraction: 0.000000
#      std_wait_fraction: 0.000000
#      p95_wait_fraction: 0.000000
#
# === Running iteration group: k=18 | file=synth_job_batches/iter-job-batches/3000-job_iter_18.csv ===
# electricity_price_per_kwh: 0.18
# cpu_power_model: affine
# default_cpu_idle_kw: 0.22
# 2 QPU(s), 2 CPU(s)
# 0.00: SIMULATION STARTED
# 0 has been processed.
# 500 has been processed.
# 1000 has been processed.
# 2500 has been processed.
# 1500 has been processed.
# 2000 has been processed.
# 3511.17: SIMULATION ENDED
# Number of jobs processed: 3000
#
# ============================================================
#                  FINAL QUANTUM CLOUD SUMMARY
# ============================================================
# Total Operational Lifetime : 3511.17 seconds
# Global Cumulative QPU Util : 87.75%
# Global Cumulative CPU Util : 7.95%
# Global Cumulative Mem Util : 11.5%
# ------------------------------------------------------------
# Individual Device Endstates:
# ============================================================
#
# Saved per-job records: runs/results_iter_18_jobs.csv (3000 jobs)
#
# === Energy/Cost Summary ===
#         number_of_jobs: 3000
#    mean_energy_qpu_kwh: 8.479407
#    mean_energy_cpu_kwh: 0.004463
#  mean_energy_total_kwh: 8.483873
#     std_energy_qpu_kwh: 9.248943
#     std_energy_cpu_kwh: 0.007325
#   std_energy_total_kwh: 9.253781
#      mean_cost_per_job: 1.527097
#       std_cost_per_job: 1.665681
#    median_cost_per_job: 0.813900
#       p95_cost_per_job: 4.999435
#           mean_phi_qpu: 0.999567
#           mean_phi_cpu: 0.000429
#            std_phi_qpu: 0.000796
#            std_phi_cpu: 0.000798
#        mean_qpu_time_s: 467.896589
#        mean_cpu_time_s: 2.812170
#         std_qpu_time_s: 508.467188
#         std_cpu_time_s: 4.606386
#         p95_qpu_time_s: 1529.330650
#         p95_cpu_time_s: 14.719435
#        mean_qpu_wait_s: 0.000000
#        mean_cpu_wait_s: 0.000000
#      mean_wait_total_s: 0.000000
#         std_qpu_wait_s: 0.000000
#         std_cpu_wait_s: 0.000000
#       std_wait_total_s: 0.000000
#       p95_wait_total_s: 0.000000
#  mean_job_turnaround_s: 482.838056
#   std_job_turnaround_s: 522.333964
# median_job_turnaround_s: 261.772550
#   p95_job_turnaround_s: 1574.879995
#      mean_turn_total_s: 470.708759
#       std_turn_total_s: 511.532173
#       p95_turn_total_s: 1537.333600
#     mean_wait_fraction: 0.000000
#      std_wait_fraction: 0.000000
#      p95_wait_fraction: 0.000000
#
# === Running iteration group: k=21 | file=synth_job_batches/iter-job-batches/3000-job_iter_21.csv ===
# electricity_price_per_kwh: 0.18
# cpu_power_model: affine
# default_cpu_idle_kw: 0.22
# 2 QPU(s), 2 CPU(s)
# 0.00: SIMULATION STARTED
# 0 has been processed.
# 500 has been processed.
# 1000 has been processed.
# 2500 has been processed.
# 1500 has been processed.
# 2000 has been processed.
# 4046.53: SIMULATION ENDED
# Number of jobs processed: 3000
#
# ============================================================
#                  FINAL QUANTUM CLOUD SUMMARY
# ============================================================
# Total Operational Lifetime : 4046.53 seconds
# Global Cumulative QPU Util : 88.86%
# Global Cumulative CPU Util : 8.21%
# Global Cumulative Mem Util : 11.84%
# ------------------------------------------------------------
# Individual Device Endstates:
# ============================================================
#
# Saved per-job records: runs/results_iter_21_jobs.csv (3000 jobs)
#
# === Energy/Cost Summary ===
#         number_of_jobs: 3000
#    mean_energy_qpu_kwh: 15.153661
#    mean_energy_cpu_kwh: 0.005203
#  mean_energy_total_kwh: 15.158866
#     std_energy_qpu_kwh: 15.136489
#     std_energy_cpu_kwh: 0.008533
#   std_energy_total_kwh: 15.142348
#      mean_cost_per_job: 2.728595
#       std_cost_per_job: 2.725623
#    median_cost_per_job: 1.908300
#       p95_cost_per_job: 8.062065
#           mean_phi_qpu: 0.999722
#           mean_phi_cpu: 0.000273
#            std_phi_qpu: 0.000643
#            std_phi_cpu: 0.000642
#        mean_qpu_time_s: 829.494853
#        mean_cpu_time_s: 3.277841
#         std_qpu_time_s: 827.165064
#         std_cpu_time_s: 5.364797
#         p95_qpu_time_s: 2438.250315
#         p95_cpu_time_s: 17.006600
#        mean_qpu_wait_s: 0.000000
#        mean_cpu_wait_s: 0.000000
#      mean_wait_total_s: 0.000000
#         std_qpu_wait_s: 0.000000
#         std_cpu_wait_s: 0.000000
#       std_wait_total_s: 0.000000
#       p95_wait_total_s: 0.000000
#  mean_job_turnaround_s: 857.859158
#   std_job_turnaround_s: 853.297312
# median_job_turnaround_s: 599.188600
#   p95_job_turnaround_s: 2507.935310
#      mean_turn_total_s: 832.772695
#       std_turn_total_s: 830.869528
#       p95_turn_total_s: 2454.837575
#     mean_wait_fraction: 0.000000
#      std_wait_fraction: 0.000000
#      p95_wait_fraction: 0.000000

# %%
df_sweep.to_csv("synth_job_batches/iteration_sweep_summary-21.csv", index=False)
print("\nSaved iteration_sweep_summary-21.csv")
print(df_sweep)
# Out:
# Saved iteration_sweep_summary-21.csv
#    number_of_jobs  mean_energy_qpu_kwh  mean_energy_cpu_kwh  \
# 0            3000             0.052683             0.000701
# 1            3000             0.105558             0.001463
# 2            3000             0.164327             0.002207
# 3            3000             0.306550             0.002944
# 4            3000             2.053575             0.003719
# 5            3000             8.479407             0.004463
# 6            3000            15.153661             0.005203
#
#    mean_energy_total_kwh  std_energy_qpu_kwh  std_energy_cpu_kwh  \
# 0               0.053388            0.022380            0.001199
# 1               0.107026            0.044376            0.002446
# 2               0.166538            0.071094            0.003657
# 3               0.309496            0.213567            0.004820
# 4               2.057297            2.175013            0.006081
# 5               8.483873            9.248943            0.007325
# 6              15.158866           15.136489            0.008533
#
#    std_energy_total_kwh  mean_cost_per_job  std_cost_per_job  \
# 0              0.022400           0.009610          0.004033
# 1              0.044470           0.019265          0.008005
# 2              0.071509           0.029977          0.012872
# 3              0.215641           0.055710          0.038815
# 4              2.179072           0.370314          0.392232
# 5              9.253781           1.527097          1.665681
# 6             15.142348           2.728595          2.725623
#
#    median_cost_per_job  ...  median_job_turnaround_s  p95_job_turnaround_s  \
# 0              0.00960  ...                  3.33810              5.768800
# 1              0.01905  ...                  6.71215             11.573460
# 2              0.02975  ...                 10.28435             18.645825
# 3              0.04790  ...                 15.94160             45.716705
# 4              0.19295  ...                 61.88770            375.860725
# 5              0.81390  ...                261.77255           1574.879995
# 6              1.90830  ...                599.18860           2507.935310
#
#    mean_turn_total_s  std_turn_total_s  p95_turn_total_s  mean_wait_fraction  \
# 0           3.378418          1.450038          5.764845                 0.0
# 1           6.789048          2.921384         11.569535                 0.0
# 2          10.501683          4.728166         18.533880                 0.0
# 3          18.813753         13.336367         45.181250                 0.0
# 4         116.043101        123.160684        367.540435                 0.0
# 5         470.708759        511.532173       1537.333600                 0.0
# 6         832.772695        830.869528       2454.837575                 0.0
#
#    std_wait_fraction  p95_wait_fraction  iterations  \
# 0                0.0                0.0           3
# 1                0.0                0.0           6
# 2                0.0                0.0           9
# 3                0.0                0.0          12
# 4                0.0                0.0          15
# 5                0.0                0.0          18
# 6                0.0                0.0          21
#
#                                         workload_csv
# 0  synth_job_batches/iter-job-batches/3000-job_it...
# 1  synth_job_batches/iter-job-batches/3000-job_it...
# 2  synth_job_batches/iter-job-batches/3000-job_it...
# 3  synth_job_batches/iter-job-batches/3000-job_it...
# 4  synth_job_batches/iter-job-batches/3000-job_it...
# 5  synth_job_batches/iter-job-batches/3000-job_it...
# 6  synth_job_batches/iter-job-batches/3000-job_it...
#
# [7 rows x 40 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

SUMMARY_CSV = "iteration_sweep_summary-21.csv"

# ----------------------------
# Load + sort
# ----------------------------
df = pd.read_csv(SUMMARY_CSV)

# Force numeric for safety (in case CSV stores as strings)
numeric_cols = [
    "iterations",
    "mean_turn_total_s", "std_turn_total_s",
    "mean_energy_total_kwh", "std_energy_total_kwh",
    "total_sim_time", "total_sim_time"
]
for c in numeric_cols:
    df[c] = pd.to_numeric(df[c], errors="coerce")

df = df.sort_values("iterations").reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'total_sim_time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 19
#      15     "mean_energy_total_kwh", "std_energy_total_kwh",
#      16     "total_sim_time", "total_sim_time"
#      17 ]
#      18 for c in numeric_cols:
# ---> 19     df[c] = pd.to_numeric(df[c], errors="coerce")
#      20
#      21 df = df.sort_values("iterations").reset_index(drop=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'total_sim_time'

# %%
from matplotlib.ticker import MaxNLocator  # 👈 1. Import the locator

LABEL_SIZE = 14
# ----------------------------
# Plot 1: iterations vs mean_turn_total_s 
# ----------------------------
fig, ax = plt.subplots(figsize=(8, 4))
ax.errorbar(
    df["iterations"],
    df["mean_turn_total_s"],
    # yerr=df["std_turn_total_s"],
    marker="o",
    linestyle="-",
    capsize=4,
)
ax.set_xlabel("Iterations", fontsize=LABEL_SIZE)
ax.set_ylabel("Total turnaround time (min)\nper job mean", fontsize=LABEL_SIZE)

# 🔑 Force x-axis ticks to be integers only
ax.xaxis.set_major_locator(MaxNLocator(integer=True)) # 👈 2. Add this line

# 🔑 Tick sizes
ax.tick_params(axis="x", labelsize=LABEL_SIZE)
ax.tick_params(axis="y", labelsize=LABEL_SIZE)

ax.grid(True, alpha=0.3)
fig.tight_layout()
fig.savefig("plot_iter_vs_turn_total_mean_std.png", dpi=300)
plt.show()

# ----------------------------
# Plot 2: iterations vs mean_energy_total_kwh 
# ----------------------------
fig, ax = plt.subplots(figsize=(8, 4))
ax.errorbar(
    df["iterations"],
    df["mean_energy_total_kwh"],
    # yerr=df["std_energy_total_kwh"],
    marker="o",
    linestyle="-",
    capsize=4,
)
ax.set_xlabel("Iterations", fontsize=LABEL_SIZE)
ax.set_ylabel("Total energy\n per job (kWh) mean", fontsize=LABEL_SIZE)

# 🔑 Force x-axis ticks to be integers only
ax.xaxis.set_major_locator(MaxNLocator(integer=True)) # 👈 2. Add this line

# 🔑 Tick sizes
ax.tick_params(axis="x", labelsize=LABEL_SIZE)
ax.tick_params(axis="y", labelsize=LABEL_SIZE)

ax.grid(True, alpha=0.3)
fig.tight_layout()
fig.savefig("plot_iter_vs_energy_total_mean_std.png", dpi=300)
plt.show()

# %%
# -----------------------------------------
# Combined Plot: iterations vs mean energy
#   - QPU on left y-axis
#   - CPU on right y-axis
# -----------------------------------------
from matplotlib.ticker import MaxNLocator, FormatStrFormatter  # 👈 1. Import FormatStrFormatter

LABEL_SIZE = 14
fig, ax1 = plt.subplots(figsize=(8, 4))

qpu_color = "#0496ff"   # blue
cpu_color = "#f25c54"   # orange/red

# QPU energy (left axis)
ax1.errorbar(
    df["iterations"],
    df["mean_energy_qpu_kwh"],
    marker="o",
    linestyle="-",
    capsize=4,
    color=qpu_color,
    label="QPU Energy (kWh)",
)
ax1.set_xlabel("Iterations", fontsize=LABEL_SIZE)
ax1.set_ylabel("Mean QPU Energy (kWh)", fontsize=LABEL_SIZE)

# 🔑 FIX: Changed 'ax' to 'ax1' and added integer formatting
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
ax1.xaxis.set_major_formatter(FormatStrFormatter('%d'))  # 👈 Prevents decimal formatting (e.g. 1.0)

ax1.tick_params(axis="x", labelsize=LABEL_SIZE)
ax1.tick_params(axis="y", labelsize=LABEL_SIZE)
ax1.grid(True, alpha=0.3)

# CPU energy (right axis)
ax2 = ax1.twinx()
ax2.errorbar(
    df["iterations"],
    df["mean_energy_cpu_kwh"],
    marker="s",
    linestyle="--",
    capsize=6,
    color=cpu_color,
    label="CPU Energy (kWh)",
)
ax2.set_ylabel("Mean CPU Energy (kWh)", fontsize=LABEL_SIZE)
ax2.tick_params(axis="y", labelsize=LABEL_SIZE)

# Combined legend
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(
    lines_1 + lines_2,
    labels_1 + labels_2,
    loc="upper left",
    frameon=True,
    fontsize=14,
)

plt.tight_layout()
plt.savefig("plot_iter_vs_mean_energy_qpu_cpu_dual_axis.png", dpi=300)
plt.show()

# %%
df

# %%
fig, ax = plt.subplots(figsize=(8, 4))

ax.errorbar(
    df["iterations"],
    df["total_sim_time"],
    marker="o",
    linestyle="-",
    capsize=4,
)

ax.set_xlabel("Iterations", fontsize=LABEL_SIZE)
ax.set_ylabel("Total simulation time", fontsize=LABEL_SIZE)

# 🔑 Tick sizes
ax.tick_params(axis="x", labelsize=LABEL_SIZE)
ax.tick_params(axis="y", labelsize=LABEL_SIZE)

ax.grid(True, alpha=0.3)
fig.tight_layout()
fig.savefig("plot_iter_vs_total_sim_time.png", dpi=300)
plt.show()

# %%
PRINTLOG = False
dd
# -----------------------------
# 0) Devices (create fresh per run recommended)
# -----------------------------
def make_devices(printlog=PRINTLOG):
    # QPUs
    ibm_strasbourg = IBM_Strasbourg(env=None, name="QPU-1", printlog=printlog)
    ibm_brussels   = IBM_Brussels(env=None, name="QPU-2", printlog=printlog)
    # CPUs
    ryzen1 = AMDRyzen("CPU-1", env=None)
    ryzen2 = AMDRyzen("CPU-2", env=None)
    return [ibm_strasbourg, ibm_brussels], [ryzen1, ryzen2]

# -----------------------------
# 1) Base cost_config (we will only update electricity_price_per_kwh)
# -----------------------------
base_cost_config = {
  "energy": {
    "electricity_price_per_kwh": 0.18,  # will be overwritten in sweep
    "default_qpu_power_kw": 50.0,
    "qpu_power_kw": {"QPU-1": 70.0, "QPU-2": 60.0},
    "cpu_power_kw": {"CPU-1": 5.0, "CPU-2": 6.5},
    "cpu_power_model": "affine",
    "default_cpu_idle_kw": 0.22,
    "default_cpu_peak_kw": 0.75,
    "default_cpu_capacity_units": 16,
    "debug_energy": False
  }
}

# -----------------------------
# 2) Create env for a run
# -----------------------------
def make_env(cost_config, printlog=PRINTLOG):
    qpus, cpus = make_devices(printlog=printlog)
    sim_env = HybridCloudSimEnv(
        qpu_devices=qpus,
        cpu_devices=cpus,
        broker_class=HybridBroker,
        job_feed_method='dispatcher',
        file_path=JOB_CSV,
        job_generation_model=None,
        printlog=printlog,
        cost_config=cost_config
    )
    return sim_env

# -----------------------------
# 4) Sweep runner
# -----------------------------
def run_iter_sweep(job_csv):
    rows = []

    for j_csv in job_csv:
        cost_config = copy.deepcopy(base_cost_config)
        cost_config["energy"]["electricity_price_per_kwh"] = float(p)

        sim_env = make_env(file_path=j, cost_config, printlog=PRINTLOG)

        print(f"\n=== Running electricity price: ${p:.2f}/kWh ===")
        # (Optional) sanity prints
        print(f"cpu_power_model: {sim_env.cost_config['energy']['cpu_power_model']}")
        print(f"default_cpu_idle_kw: {sim_env.cost_config['energy']['default_cpu_idle_kw']}")

        sim_env.run()

        job_records = sim_env.job_records_manager.job_records
        df_jobs = build_job_energy_df(job_records)

        # Save one row per price point
        summary = get_summary(df_jobs)
        summary["electricity_price_per_kwh"] = float(p)
        rows.append(summary)

    df_sweep = pd.DataFrame(rows).sort_values("electricity_price_per_kwh").reset_index(drop=True)
    return df_sweep

# %%
# -----------------------------
# 5) Execute sweep
# -----------------------------

import matplotlib.pyplot as plt

JOB_CSV = ["synth_job_batches/5000-job_iter_3.csv", 
           "synth_job_batches/5000-job_iter_6.csv", 
           "synth_job_batches/5000-job_iter_9.csv",
           "synth_job_batches/5000-job_iter_12.csv"]

df_sweep = run_iter_sweep(job_csv)

df_sweep.to_csv("electricity_price_sensitivity.csv", index=False)
print("\nSaved electricity_price_sensitivity.csv")
