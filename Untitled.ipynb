# %%
req_iter = 5
cur_iter = 0

while cur_iter < req_iter: 
    print(f"cur_iter: {cur_iter}")
    cur_iter += 1
    if cur_iter >= req_iter: 
        print(f"loop finished")
# Out:
# cur_iter: 0
# cur_iter: 1
# cur_iter: 2
# cur_iter: 3
# cur_iter: 4
# loop finished
